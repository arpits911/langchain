# %%
pip install langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.3.1-py3-none-any.whl.metadata (996 bytes)
# Collecting langchain-core<1.0.0,>=0.3.70 (from langchain-huggingface)
#   Downloading langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Collecting tokenizers>=0.19.1 (from langchain-huggingface)
#   Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting huggingface-hub>=0.33.4 (from langchain-huggingface)
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading langsmith-0.4.37-py3-none-any.whl.metadata (14 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.11.7)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading uuid_utils-0.15.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading orjson-3.11.5-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.32.4)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface)
#   Downloading zstandard-0.25.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.1)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.33.4->langchain-huggingface)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.33.4->langchain-huggingface)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub>=0.33.4->langchain-huggingface)
#   Using cached hf_xet-1.5.0-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (4.67.1)
# Collecting typer (from huggingface-hub>=0.33.4->langchain-huggingface)
#   Downloading typer-0.23.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from typer->huggingface-hub>=0.33.4->langchain-huggingface) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer->huggingface-hub>=0.33.4->langchain-huggingface)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface-hub>=0.33.4->langchain-huggingface)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface-hub>=0.33.4->langchain-huggingface)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface-hub>=0.33.4->langchain-huggingface)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/arpitsingh/Desktop/workspaces/github_codes/env/lib/python3.9/site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.33.4->langchain-huggingface) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.33.4->langchain-huggingface)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading langchain_huggingface-0.3.1-py3-none-any.whl (27 kB)
# Downloading langchain_core-0.3.86-py3-none-any.whl (461 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.37-py3-none-any.whl (396 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.15.0-cp39-cp39-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (572 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.3/572.3 kB 97.2 kB/s eta 0:00:00:--:--
# Downloading huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.2/625.2 kB 162.9 kB/s eta 0:00:00a 0:00:01
# Using cached hf_xet-1.5.0-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.5-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (245 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Downloading zstandard-0.25.0-cp39-cp39-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.6/640.6 kB 804.6 kB/s eta 0:00:00:--:--
# Downloading typer-0.23.2-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: zstandard, uuid-utils, tenacity, shellingham, orjson, mdurl, jsonpointer, hf-xet, fsspec, filelock, annotated-doc, requests-toolbelt, markdown-it-py, jsonpatch, rich, typer, langsmith, langchain-core, huggingface-hub, tokenizers, langchain-huggingface
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [langchain-huggingface]ingface-hub]
# Successfully installed annotated-doc-0.0.4 filelock-3.19.1 fsspec-2025.10.0 hf-xet-1.5.0 huggingface-hub-1.8.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.86 langchain-huggingface-0.3.1 langsmith-0.4.37 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.11.5 requests-toolbelt-1.0.0 rich-15.0.0 shellingham-1.5.4 tenacity-9.1.2 tokenizers-0.22.2 typer-0.23.2 uuid-utils-0.15.0 zstandard-0.25.0
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN")
)
model = ChatHuggingFace(llm=llm)
result = model.invoke("What is the capital of Delhi?")
print(result)
# Out:
# content='Delhi is a union territory of India and a state, and it does not have a state capital because it is a union territory.  However, the National Capital Territory (NCT) of Delhi is a separate entity with its own government.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 42, 'total_tokens': 92}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': 'vllm-0.21.0-dbb32ef8', 'finish_reason': 'stop', 'logprobs': None} id='run--019ea7a7-8a6e-7c40-93a7-307c372f838b-0' usage_metadata={'input_tokens': 42, 'output_tokens': 50, 'total_tokens': 92}
